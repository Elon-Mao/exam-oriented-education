# %% [markdown]
# 现实问题中，看图像需注意函数的变量范围，例如下图，甲组x的范围是$0 \le x \le 6$, 乙组x的范围是$0 \le x \le 4.8$

# %% [markdown]
# <svg width="193" height="172" xmlns="http://www.w3.org/2000/svg">
#   <image href="data:image/png;base64,..." width="193" height="172" />
# </svg>
