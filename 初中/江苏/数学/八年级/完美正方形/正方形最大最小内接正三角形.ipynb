# %% [markdown]
# <svg xmlns="http://www.w3.org/2000/svg" width="180" height="180"><image href="data:image/png;base64,..." height="180" width="180" /></svg>

# %% [markdown]
# 将三角形一边上的中点和正方形两个顶点相连，先证明图中相关的点在绿圆上，再证明红色三角形是正三角形，得出结论内接三角形边上中点固定，从而得出最大最小的边长
