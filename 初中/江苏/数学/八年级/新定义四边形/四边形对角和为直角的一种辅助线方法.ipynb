# %% [markdown]
# <svg xmlns="http://www.w3.org/2000/svg" width="150" height="150"><image href="data:image/png;base64,..." height="150" width="150" /></svg>

# %% [markdown]
# 如图可以构造$\angle ABF$ 等于$\angle ADC$，从而使得$\angle DAB$ + $\angle DCB$等于90度的条件得以使用
